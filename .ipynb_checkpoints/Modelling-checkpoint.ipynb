# %%
import pandas as pd
import numpy as np
import itertools
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
from tqdm import tqdm_notebook as tqdm
import _pickle as pickle
plt.style.use('ggplot')

# %%
bc = pd.read_csv('BTC-USD.csv')
bc.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 358  2019-12-10  7397.134277  7424.022949  7246.043945  7278.119629
# 359  2019-12-11  7277.197754  7324.156250  7195.527344  7217.427246
# 360  2019-12-12  7216.738770  7266.639648  7164.741211  7243.134277
# 361  2019-12-13  7244.662109  7293.560547  7227.122559  7269.684570
# 362  2019-12-17  6932.012207  6951.695801  6928.623535  6929.553223
#
#        Adj Close       Volume
# 358  7278.119629  18249031194
# 359  7217.427246  16350490689
# 360  7243.134277  18927080224
# 361  7269.684570  17125736940
# 362  6929.553223  20084940800

# %%
bc['Date'] = pd.to_datetime(bc.Date)
bc.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
bc = bc[['Close']].loc['2017-01-01':]
bc.head()
# Out:
#             Close
# 202  11450.846680
# 203  12285.958008
# 204  12573.812500
# 205  12156.512695
# 206  11358.662109

# %%
with open("curr_bitcoin.pickle", 'wb') as fp:
    pickle.dump(bc, fp)

# %%
bc.plot(figsize=(16,5))

plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.title('Bitcoin Price')
plt.savefig('btcprice.png')
plt.show()

# %%
# Differencing the price
bc_diff = bc.diff(1).dropna()

# Plotting the differences daily
bc_diff.plot(figsize=(12,5))
plt.title('Plot of the Daily Changes in Price for BTC')
plt.ylabel('Change in USD')
plt.show()

# %%
results = adfuller(bc_diff.Close)
print(f"P-value: {results[1]}")
# Out:
# P-value: 7.766185891924754e-07
